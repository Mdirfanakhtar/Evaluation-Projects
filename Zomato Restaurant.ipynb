# %% [markdown]
# # Zomato Restaurant

# %% [markdown]
# ### importing library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1= pd.read_csv("zomato.csv")
df2= pd.read_excel("Country-Code.xlsx")

# %%
df=pd.merge(df1, df2, on= 'Country Code', how= 'left')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#Knowing my culomns
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
# find data type by info
# Object: Categorical
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
print('Here, there is a list of Zomato country:')
for i in pd.unique(df.Country): print(i)
print('Total number of countries is:', len(pd.unique(df.Country)))
# Out:
# Here, there is a list of Zomato country:
# Phillipines
# Brazil
# United States
# Australia
# Canada
# Singapore
# UAE
# India
# Indonesia
# New Zealand
# United Kingdom
# Qatar
# South Africa
# Sri Lanka
# Turkey
# Total number of countries is: 15

# %%
# Review descriptive data
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.Country.value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
df.Country.value_counts().index
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
country_val = df.Country.value_counts().values
country_val
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %% [markdown]
# ## Data Analysis

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.heatmap(df.isnull(), yticklabels =False, cbar=False, cmap= 'viridis')
# Out:
# <Axes: >

# %%
country_name= df[:3]

# %% [markdown]
# The value between in 9551 is too small so did not show in heatmap

# %%
plt.pie(country_val[:3], labels=country_name[:3],autopct ='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x18a48c576a0>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'Restaurant ID'),
#   Text(1.077281715838356, -0.22240527134123297, 'Restaurant Name'),
#   Text(1.0995865153823035, -0.03015783794312073, 'Country Code')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %%
df.groupby(['Aggregate rating','Rating color','Rating text']).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %%
df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index()
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2148
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    27
# 6                2.3          Red        Poor    47
# 7                2.4          Red        Poor    87
# 8                2.5       Orange     Average   110
# 9                2.6       Orange     Average   191
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   315
# 12               2.9       Orange     Average   381
# 13               3.0       Orange     Average   468
# 14               3.1       Orange     Average   519
# 15               3.2       Orange     Average   522
# 16               3.3       Orange     Average   483
# ...

# %%
rating = df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
rating
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [raw]
# Observation:
# When Rating is between 4.5 to 4.9 it means Excellent
# When Rating is between 4.0 to 4.4 it means Very Good
# When Rating is between 3.5 to 3.9 it means Good
# When Rating is between 2.5 to 3.4 it means Average
# When Rating is between 2.0 to 2.4 it means Poor

# %%
rating.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x= 'Aggregate rating', y='Rating Count', data= rating);

# %%
sns.barplot(x= 'Aggregate rating', y='Rating Count', data= rating, hue='Rating color');

# %%
sns.barplot(x= 'Aggregate rating', y='Rating Count', data= rating,hue='Rating color', palette=['white', 'yellow', 'green', 'orange','blue','black']);

# %%
sns.barplot(x= 'Aggregate rating', y='Rating color', data= rating, palette=['white', 'yellow', 'green', 'orange','blue','black']);

# %% [raw]
# Observation:
# 1- Not Rated count is very high
# 2- Maximum Number of rating are between 2.5 to 3.6

# %%
## Countplot
sns.countplot(x='Rating color', data= rating, palette= ['white', 'yellow', 'green', 'orange','blue','black'])
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %% [markdown]
# ##### Find country names that have given zero rating

# %%
df[df['Rating color']== 'White']
# Out:
#       Restaurant ID         Restaurant Name  Country Code            City  \
# 30          6600060          Sandubas Caf��            30       Bras�_lia
# 58          7305048   Quiosque Chopp Brahma            30  Rio de Janeiro
# 69          6710645        Cantinho da Gula            30      S��o Paulo
# 77          6701419           Divino Fog��o            30      S��o Paulo
# 78          6703956             Super Grill            30      S��o Paulo
# ...             ...                     ...           ...             ...
# 9109       18277023           Bread & Pasta             1           Noida
# 9110       18313203           Chillies Cafe             1           Noida
# 9111       18254559                Platters             1           Noida
# 9112       18255132               The Grand             1           Noida
# 9351       18273002  Damascena Coffee House           215      Birmingham
#
#                                                 Address  \
# ...

# %%
df[df['Rating color']== 'White'].groupby(['Aggregate rating','Country']).size().reset_index()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %% [markdown]
# #### Observation:

# %% [markdown]
# find out which currency is used by which country

# %%
df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(��)    80
# 14   United States               Dollar($)   434

# %% [markdown]
# Which countries do have online deliveries

# %%
df[df['Has Online delivery']=='Yes'].Country.value_counts()
# Out:
# Country
# India    2423
# UAE        28
# Name: count, dtype: int64

# %%
df[['Has Online delivery', 'Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %% [markdown]
# Online deliveries are available in India and UAE

# %%
## Create a pie chart for cities distribution
city_values=df.City.value_counts().values
city_labels=df.City.value_counts().values

# %%
plt.pie(city_values[:5],labels=city_labels[:5], autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x18a48c975e0>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, '5473'),
#   Text(0.0623675251198054, -1.0982305276263407, '1118'),
#   Text(0.8789045225625368, -0.6614581167535246, '1080'),
#   Text(1.0922218418223437, -0.13058119407559224, '251'),
#   Text(1.099946280005612, -0.010871113182029924, '25')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %% [markdown]
# #### Heatmap

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df[["Restaurant ID","Country Code","Longitude","Latitude","Average Cost for two","Price range","Aggregate rating","Votes"]].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Feature Engineering:

# %% [markdown]
# Rating Categories

# %%
def categorize_rating(rating):
    if 4.5 <= rating <= 4.9:
        return 'Excellent'
    elif 4.0 <= rating <= 4.4:
        return 'Very Good'
    elif 3.5 <= rating <= 3.9:
        return 'Good'
    elif 2.5 <= rating <= 3.4:
        return 'Average'
    elif 2.0 <= rating <= 2.4:
        return 'Poor'
    else:
        return 'Not Categorized'  

# Apply the function to create a new 'Rating Category' column
df['Rating Category'] = df['Aggregate rating'].apply(categorize_rating)

# %% [markdown]
# Online Delivery Indicator

# %%
# Convert 'Has Online delivery' to binary indicator
df['Online Delivery Indicator'] = (df['Has Online delivery'] == 'Yes').astype(int)

# %% [markdown]
# City Population Categories (Hypothetical Example)

# %%
def categorize_city_population(population):
    if population > 1000000:
        return 'Metropolitan'
    elif 500000 <= population <= 1000000:
        return 'Urban'
    else:
        return 'Rural'
df['Country Votes Category'] = df['Votes'].apply(categorize_city_population)

# %% [markdown]
# Numeric Feature Scaling (if needed)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['Average Cost for two', 'Votes']] = scaler.fit_transform(df[['Average Cost for two', 'Votes']])

# %% [markdown]
# Geographical Features

# %%
# Define latitude and longitude of the reference location
latitude_ref = 40.7128  # Example latitude of New York City
longitude_ref = -74.0060  # Example longitude of New York City

from geopy.distance import geodesic

def calculate_distance(lat1, lon1, ref_location):
    return geodesic((lat1, lon1), ref_location).km
df['Distance from Reference'] = df.apply(lambda row: calculate_distance(row['Latitude'], row['Longitude'], (latitude_ref, longitude_ref)), axis=1)

# %% [markdown]
# ### Outlier Detection:

# %% [markdown]
# Z-score Method:

# %%
from scipy.stats import zscore

z_scores = zscore(df[['Average Cost for two', 'Votes']])
threshold = 3
outliers = (np.abs(z_scores) > threshold).any(axis=1)
df_no_outliers = df[~outliers]

# %% [markdown]
# Interquartile Range (IQR) Method:

# %%
# Compute the first quartile (Q1) and third quartile (Q3)
Q1 = df['Votes'].quantile(0.25)
Q3 = df['Votes'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = (df['Votes'] < lower_bound) | (df['Votes'] > upper_bound)

df_no_outliers = df[~outliers]

# %% [markdown]
# ### Dimensionality Reduction

# %% [markdown]
# PCA for dimensionality reduction

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

features = ['Average Cost for two', 'Votes']
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[features])
n_components = 2  
pca = PCA(n_components=n_components)
principal_components = pca.fit_transform(scaled_features)
columns = [f'PC{i+1}' for i in range(n_components)]
df_pca = pd.DataFrame(data=principal_components, columns=columns)
df_pca_final = pd.concat([df.drop(columns=features), df_pca], axis=1)
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.53389162 0.46610838]

# %% [markdown]
# ### Handling Imbalanced Data:

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE

numerical_cols = ['Average Cost for two', 'Votes']  
categorical_cols = ['City', 'Cuisines']  

X = df[numerical_cols + categorical_cols]
y = df['Rating Category']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', numerical_cols),  
        ('cat', OneHotEncoder(), categorical_cols)  
    ],
    remainder='drop'  
)

X_encoded = preprocessor.fit_transform(X)
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X_encoded, y)
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(X_train, y_train)
y_pred = rf_classifier.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#         Average       0.78      0.77      0.78       786
#       Excellent       0.98      0.99      0.98       741
#            Good       0.74      0.76      0.75       732
# Not Categorized       1.00      1.00      1.00       752
#            Poor       0.91      0.93      0.92       736
#       Very Good       0.93      0.88      0.91       738
#
#        accuracy                           0.89      4485
#       macro avg       0.89      0.89      0.89      4485
#    weighted avg       0.89      0.89      0.89      4485

# %% [markdown]
# ## Classification Models:

# %% [markdown]
# RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, mean_squared_error, confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder

rf_classifier = RandomForestClassifier(random_state=42)
label_encoder = LabelEncoder()
y_test_encoded = label_encoder.fit_transform(y_test)
y_pred_encoded = label_encoder.transform(y_pred)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

mse = mean_squared_error(y_test_encoded, y_pred_encoded)
print("Mean Squared Error (MSE):", mse)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.8891861761426979
# Mean Squared Error (MSE): 0.9023411371237459
# Confusion Matrix:
# [[606   0 128   0  46   6]
#  [  0 735   0   0   1   5]
#  [116   5 555   0  19  37]
#  [  0   0   1 751   0   0]
#  [ 36   0  12   0 688   0]
#  [ 16  12  51   0   6 653]]
# Classification Report:
#                  precision    recall  f1-score   support
#
#         Average       0.78      0.77      0.78       786
#       Excellent       0.98      0.99      0.98       741
#            Good       0.74      0.76      0.75       732
# Not Categorized       1.00      1.00      1.00       752
#            Poor       0.91      0.93      0.92       736
#       Very Good       0.93      0.88      0.91       738
#
#        accuracy                           0.89      4485
#       macro avg       0.89      0.89      0.89      4485
#    weighted avg       0.89      0.89      0.89      4485

# %% [markdown]
# Logistic Regression:

# %%
from sklearn.linear_model import LogisticRegression

logreg_classifier = LogisticRegression(random_state=42)

logreg_classifier.fit(X_train, y_train)
y_pred = logreg_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

mse = mean_squared_error(y_test_encoded, y_pred_encoded)
print("Mean Squared Error (MSE):", mse)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.72396878483835
# Mean Squared Error (MSE): 0.9023411371237459
# Confusion Matrix:
# [[301   3  80 253 139  10]
#  [  6 690  20   0   0  25]
#  [157  15 411   7  65  77]
#  [  4   0   0 746   2   0]
#  [ 94   1  13  34 594   0]
#  [ 26  78 108   0  21 505]]
# C:\Users\mdirf\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Support Vector Machines (SVM):

# %%
from sklearn.svm import SVC

svm_classifier = SVC(kernel='linear', random_state=42)
svm_classifier.fit(X_train, y_train)
y_pred = svm_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

mse = mean_squared_error(y_test_encoded, y_pred_encoded)
print("Mean Squared Error (MSE):", mse)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.7282051282051282
# Mean Squared Error (MSE): 0.9023411371237459
# Confusion Matrix:
# [[329   1  76 215 158   7]
#  [ 12 703  11   0   1  14]
#  [177   8 411   1  71  64]
#  [ 21   0   2 728   0   1]
#  [106   0   7  31 592   0]
#  [ 28  80  99   0  28 503]]
# Classification Report:
#                  precision    recall  f1-score   support
#
#         Average       0.49      0.42      0.45       786
#       Excellent       0.89      0.95      0.92       741
#            Good       0.68      0.56      0.61       732
# Not Categorized       0.75      0.97      0.84       752
#            Poor       0.70      0.80      0.75       736
#       Very Good       0.85      0.68      0.76       738
#
#        accuracy                           0.73      4485
#       macro avg       0.73      0.73      0.72      4485
#    weighted avg       0.72      0.73      0.72      4485

# %% [markdown]
# Gradient Boosting Machines (GBM):

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbm_classifier = GradientBoostingClassifier(random_state=42)
gbm_classifier.fit(X_train, y_train)
y_pred = gbm_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

mse = mean_squared_error(y_test_encoded, y_pred_encoded)
print("Mean Squared Error (MSE):", mse)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.7536231884057971
# Mean Squared Error (MSE): 0.9023411371237459
# Confusion Matrix:
# [[547   0 118   0 103  18]
#  [  0 675  18   0   0  48]
#  [116  18 376   0  74 148]
#  [  1   0   0 751   0   0]
#  [ 77   2  39   0 615   3]
#  [ 21 154 124   0  23 416]]
# Classification Report:
#                  precision    recall  f1-score   support
#
#         Average       0.72      0.70      0.71       786
#       Excellent       0.80      0.91      0.85       741
#            Good       0.56      0.51      0.53       732
# Not Categorized       1.00      1.00      1.00       752
#            Poor       0.75      0.84      0.79       736
#       Very Good       0.66      0.56      0.61       738
#
#        accuracy                           0.75      4485
#       macro avg       0.75      0.75      0.75      4485
#    weighted avg       0.75      0.75      0.75      4485

# %% [markdown]
# #### Conculusion

# %% [markdown]
# The best model is RandomForestClassifier.
